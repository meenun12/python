# %%
from PIL import Image
mac = Image.open('example.jpg')
# Note this is a specialized file type from PIL (pillow)
type(mac)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1993x1257 at 0x7F42AC7C5D30>

# %%
mac.filename
# Out:
# 'example.jpg'

# %%
mac.format_description
# Out:
# 'JPEG (ISO 10918)'

# %%
mac.crop((0,0,100,100))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7F42AD52CA30>

# %%
pencils = Image.open("pencils.jpg")

# %%
pencils
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1950x1300 at 0x7F42AC772F10>

# %%
pencils.size
# Out:
# (1950, 1300)

# %%
# Start at top corner (0,0)
x = 0
y = 0

# Grab about 10% in y direction , and about 30% in x direction
w = 1950/3
h = 1300/10

pencils.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGB size=650x130 at 0x7F42AC772CD0>
